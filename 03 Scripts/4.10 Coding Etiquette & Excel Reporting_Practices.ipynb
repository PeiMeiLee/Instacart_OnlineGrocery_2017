# %% [markdown]
# ## Example of using Excel with Python
# ### Crosstabs in Python

# %%
# Impor tlibraries
import pandas as pd
import numpy as np
import os

# %%
# Import data

path = r'/Users/peimei/09-2023 Instacart Basket Analysis'
ords_prods_custs = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_customers.pkl'))
ords_prods_custs.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    no_of_days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                          NaN         196                  1          0
# 1                         15.0         196                  1          1
# 2                         21.0         196                  1          1
# 3                         29.0         196                  1          1
# 4                         28.0         196                  1          1
#
#   product_name  ...   order_frequency_flag  first_name  surname  gender  \
# ...

# %%
# Create a crosstab

crosstab = pd.crosstab(ords_prods_custs['no_of_days_since_last_order'], ords_prods_custs['order_number'], dropna = False)

# %%
# Copy the table to clipboard

crosstab.to_clipboard()

# %% [markdown]
# ### In the example above, for instance, you could include a screenshot of the Excel table in your report and write something along the lines of “We found missing values in this column but conducted an analysis that revealed them to be fine in context. Please confirm whether our assumption is correct.”

# %%
ords_prods_custs.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_day_of_week',
#        'order_hour_of_day', 'no_of_days_since_last_order', 'product_id',
#        'add_to_cart_order', 'reordered', 'product_name', 'aisle_id',
#        'department_id', 'prices', 'merge_result', 'price_range_loc',
#        'busiest day', 'busiest days', 'busiest_period_of_day', 'max_order',
#        'loyalty_flag', 'price_mean', 'spending_flag',
#        'median_days_since_last_order', 'order_frequency_flag', 'first_name',
#        'surname', 'gender', 'state', 'age', 'date_joined', 'count_dependants',
#        'fam_status', 'income'],
#       dtype='object')
